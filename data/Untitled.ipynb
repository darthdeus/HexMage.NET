# %%
import numpy as np
import pandas as pd

# %%
pd.DataFrame.from_csv("responses.csv")
# Out:
#                     Číslo hry - NEMĚNIT automaticky předvyplněno  \
# Timestamp
# 2017-04-26 02:37:05             data/questionnaire\0evo-save.txt
# 2017-04-26 15:06:24             data/questionnaire\0evo-save.txt
# 2017-04-26 17:33:03             data/questionnaire\0evo-save.txt
# 2017-04-26 19:40:37             data/questionnaire\0evo-save.txt
# 2017-04-27 16:52:13             data/questionnaire\0evo-save.txt
# 2017-04-29 09:30:39             data/questionnaire\0evo-save.txt
# 2017-05-01 14:53:12             data/questionnaire\0evo-save.txt
# 2017-05-01 20:48:28             data/questionnaire\0evo-save.txt
# 2017-04-26 02:40:07            data/questionnaire\10evo-save.txt
# 2017-04-26 15:11:52            data/questionnaire\10evo-save.txt
# 2017-04-26 17:47:18            data/questionnaire\10evo-save.txt
# 2017-04-26 19:45:24            data/questionnaire\10evo-save.txt
# 2017-04-27 17:03:37            data/questionnaire\10evo-save.txt
# ...
